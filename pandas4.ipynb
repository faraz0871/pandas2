# %%
print("faraz")
# Out:
# faraz

# %%
import pandas as pd

# %%
pip install pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop("PassengerId" ,axis=1)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
 df = df.drop(3)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
print("faraz")
# Out:
# faraz

# %%
d = {'key1':[1,2,3,4,5],
     'key2':[0,8,7,2,1],
     'key3':[2,3,4,5,6],
     'key4':[4,4,3,2,50]
    }

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3  key4
# 0     1     0     2     4
# 1     2     8     3     4
# 2     3     7     4     3
# 3     4     2     5     2
# 4     5     1     6    50

# %%
df1 = pd.read_csv("faraz.csv")

# %%
df1
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df1.dropna(axis=1)
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df2 = pd.read_csv("faraz.csv")

# %%
df2
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df2.dropna(axis=1) ## it will remove the column which is having the na value(employee markne)
# Out:
#     Serial Number                   Company Name         Description  Leave
# 0   9788189999599                 TALES OF SHIVA                mark     34
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY                Mark      0
# 2   9780198082897                       MY KUMAN                Mark      0
# 3   9780007880331        THE GOD OF SMAAL THINGS  4TH HARPER COLLINS      2
# 4   9780545060455               THE BLACK CIRCLE  4TH HARPER COLLINS      0
# ..            ...                            ...                 ...    ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS                 ACK      0
# 95  9788184821543           MORE TALES OF BIRBAL                 ACK      0
# 96  9788184821550         TALES FROM THE JATAKAS                 ACK      0
# 97  9788184821567               RAMarkS OF MEWAR                 ACK      0
# 98  9788184821574       THE SONS OF THE PANDAVAS                 ACK      0
#
# [99 rows x 4 columns]

# %%
#list(df2["Employee Markme"])

# %%
df3 = df2.fillna("faraz")

# %%
df2
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df3
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df3
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df3.columns
# Out:
# Index(['Serial Number', 'Company Name', 'Employee Markme', 'Description',
#        'Leave'],
#       dtype='object')

# %%
df3
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark     34
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df3.set_index("Description")
# Out:
#                     Serial Number                   Company Name  \
# Description
# mark                9788189999599                 TALES OF SHIVA
# Mark                9780099578079      1Q84 THE COMPLETE TRILOGY
# Mark                9780198082897                       MY KUMAN
# 4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ...                           ...                            ...
# ACK                 9788184821536  MORE STORIES FROM THE JATAKAS
# ACK                 9788184821543           MORE TALES OF BIRBAL
# ACK                 9788184821550         TALES FROM THE JATAKAS
# ACK                 9788184821567               RAMarkS OF MEWAR
# ACK                 9788184821574       THE SONS OF THE PANDAVAS
#
#                     Employee Markme  Leave
# Description
# mark                           Mark     34
# Mark                HARUKI MURAKAMI      0
# ...

# %%
df3.set_index("Description",inplace=True)

# %%
df3
# Out:
#                     Serial Number                   Company Name  \
# Description
# mark                9788189999599                 TALES OF SHIVA
# Mark                9780099578079      1Q84 THE COMPLETE TRILOGY
# Mark                9780198082897                       MY KUMAN
# 4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ...                           ...                            ...
# ACK                 9788184821536  MORE STORIES FROM THE JATAKAS
# ACK                 9788184821543           MORE TALES OF BIRBAL
# ACK                 9788184821550         TALES FROM THE JATAKAS
# ACK                 9788184821567               RAMarkS OF MEWAR
# ACK                 9788184821574       THE SONS OF THE PANDAVAS
#
#                     Employee Markme  Leave
# Description
# mark                           Mark     34
# Mark                HARUKI MURAKAMI      0
# ...

# %%
df3
# Out:
#                     Serial Number                   Company Name  \
# Description
# mark                9788189999599                 TALES OF SHIVA
# Mark                9780099578079      1Q84 THE COMPLETE TRILOGY
# Mark                9780198082897                       MY KUMAN
# 4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ...                           ...                            ...
# ACK                 9788184821536  MORE STORIES FROM THE JATAKAS
# ACK                 9788184821543           MORE TALES OF BIRBAL
# ACK                 9788184821550         TALES FROM THE JATAKAS
# ACK                 9788184821567               RAMarkS OF MEWAR
# ACK                 9788184821574       THE SONS OF THE PANDAVAS
#
#                     Employee Markme  Leave
# Description
# mark                           Mark     34
# Mark                HARUKI MURAKAMI      0
# ...

# %%
df3.reset_index(inplace=True)

# %%
df3
# Out:
#            Description  Serial Number                   Company Name  \
# 0                 mark  9788189999599                 TALES OF SHIVA
# 1                 Mark  9780099578079      1Q84 THE COMPLETE TRILOGY
# 2                 Mark  9780198082897                       MY KUMAN
# 3   4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4   4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ..                 ...            ...                            ...
# 94                 ACK  9788184821536  MORE STORIES FROM THE JATAKAS
# 95                 ACK  9788184821543           MORE TALES OF BIRBAL
# 96                 ACK  9788184821550         TALES FROM THE JATAKAS
# 97                 ACK  9788184821567               RAMarkS OF MEWAR
# 98                 ACK  9788184821574       THE SONS OF THE PANDAVAS
#
#     Employee Markme  Leave
# 0              Mark     34
# 1   HARUKI MURAKAMI      0
# 2              Mark      0
# ...

# %%
df3
# Out:
#            Description  Serial Number                   Company Name  \
# 0                 mark  9788189999599                 TALES OF SHIVA
# 1                 Mark  9780099578079      1Q84 THE COMPLETE TRILOGY
# 2                 Mark  9780198082897                       MY KUMAN
# 3   4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4   4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ..                 ...            ...                            ...
# 94                 ACK  9788184821536  MORE STORIES FROM THE JATAKAS
# 95                 ACK  9788184821543           MORE TALES OF BIRBAL
# 96                 ACK  9788184821550         TALES FROM THE JATAKAS
# 97                 ACK  9788184821567               RAMarkS OF MEWAR
# 98                 ACK  9788184821574       THE SONS OF THE PANDAVAS
#
#     Employee Markme  Leave
# 0              Mark     34
# 1   HARUKI MURAKAMI      0
# 2              Mark      0
# ...

# %%
df3.drop("Leave",axis=1,inplace=True)

# %%
df3
# Out:
#            Description  Serial Number                   Company Name  \
# 0                 mark  9788189999599                 TALES OF SHIVA
# 1                 Mark  9780099578079      1Q84 THE COMPLETE TRILOGY
# 2                 Mark  9780198082897                       MY KUMAN
# 3   4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4   4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ..                 ...            ...                            ...
# 94                 ACK  9788184821536  MORE STORIES FROM THE JATAKAS
# 95                 ACK  9788184821543           MORE TALES OF BIRBAL
# 96                 ACK  9788184821550         TALES FROM THE JATAKAS
# 97                 ACK  9788184821567               RAMarkS OF MEWAR
# 98                 ACK  9788184821574       THE SONS OF THE PANDAVAS
#
#     Employee Markme
# 0              Mark
# 1   HARUKI MURAKAMI
# 2              Mark
# 3     ARUNDHATI ROY
# 4              Mark
# ...

# %%
df3
# Out:
#            Description  Serial Number                   Company Name  \
# 0                 mark  9788189999599                 TALES OF SHIVA
# 1                 Mark  9780099578079      1Q84 THE COMPLETE TRILOGY
# 2                 Mark  9780198082897                       MY KUMAN
# 3   4TH HARPER COLLINS  9780007880331        THE GOD OF SMAAL THINGS
# 4   4TH HARPER COLLINS  9780545060455               THE BLACK CIRCLE
# ..                 ...            ...                            ...
# 94                 ACK  9788184821536  MORE STORIES FROM THE JATAKAS
# 95                 ACK  9788184821543           MORE TALES OF BIRBAL
# 96                 ACK  9788184821550         TALES FROM THE JATAKAS
# 97                 ACK  9788184821567               RAMarkS OF MEWAR
# 98                 ACK  9788184821574       THE SONS OF THE PANDAVAS
#
#     Employee Markme
# 0              Mark
# 1   HARUKI MURAKAMI
# 2              Mark
# 3     ARUNDHATI ROY
# 4              Mark
# ...

# %%
print("faraz")
# Out:
# faraz

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
## group by operations and give the count
g = df.groupby("Survived")

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_738/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_738/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1 = df.groupby("Pclass")

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_738/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_738/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()
# Out:
# /tmp/ipykernel_738/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex   Age  SibSp  Parch  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male  80.0      3      4
# 2         del Carlo, Mr. Sebastiano         1  male  70.0      3      3
# 3       van Melkebeke, Mr. Philemon         1  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
## if you want only fare
g1.max()["Fare"]
# Out:
# /tmp/ipykernel_738/1753050449.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()["Fare"]
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max().T  ## row will become column and column will become row (T means transpose)
# Out:
# /tmp/ipykernel_738/695647134.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T  ## row will become column and column will become row (T means transpose)
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# ...

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_738/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
## making subset of data
df5= df[["Name" ,"Survived","Pclass"]][0:5]

# %%
df6= df[["Name" ,"Survived","Pclass"]][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
## in pandas you  can merge the data either horizontally or the vertically
pd.concat([df5,df6]) ## axis=0(means row wise) axis=1(means column wise)
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5,df6],axis=1)

# %%
df7.fillna("faraz")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                              faraz    faraz  faraz
# 6                                              faraz    faraz  faraz
# 7                                              faraz    faraz  faraz
# 8                                              faraz    faraz  faraz
# 9                                              faraz    faraz  faraz
#
#                                                 Name Survived Pclass
# 0                                              faraz    faraz  faraz
# 1                                              faraz    faraz  faraz
# ...

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
data1 = pd.DataFrame({'key1' : [1,2,4,5,6],
                      'key2' : [4,5,6,7,8],
                      'key3' : [8,3,5,6,6]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     3
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2 = pd.DataFrame({'key1' : [1,23,4,55,6],
                      'key5' : [43,53,6,7,8],
                      'key6' : [8,34,5,7,36]})

# %%
data2
# Out:
#    key1  key5  key6
# 0     1    43     8
# 1    23    53    34
# 2     4     6     5
# 3    55     7     7
# 4     6     8    36

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     3
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key5  key6
# 0     1    43     8
# 1    23    53    34
# 2     4     6     5
# 3    55     7     7
# 4     6     8    36

# %%
## merge operation
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key5  key6
# 0     1     4     8    43     8
# 1     4     6     5     6     5
# 2     6     8     6     8    36

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     3
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key5  key6
# 0     1    43     8
# 1    23    53    34
# 2     4     6     5
# 3    55     7     7
# 4     6     8    36

# %%
pd.merge(data1,data2,how="left")
# Out:
#    key1  key2  key3  key5  key6
# 0     1     4     8  43.0   8.0
# 1     2     5     3   NaN   NaN
# 2     4     6     5   6.0   5.0
# 3     5     7     6   NaN   NaN
# 4     6     8     6   8.0  36.0

# %%
pd.merge(data1,data2,how="right")
# Out:
#    key1  key2  key3  key5  key6
# 0     1   4.0   8.0    43     8
# 1    23   NaN   NaN    53    34
# 2     4   6.0   5.0     6     5
# 3    55   NaN   NaN     7     7
# 4     6   8.0   6.0     8    36

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     3
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key5  key6
# 0     1    43     8
# 1    23    53    34
# 2     4     6     5
# 3    55     7     7
# 4     6     8    36

# %%
pd.merge(data1,data2,how="outer") ## unmatching terms also be taken in last
# Out:
#    key1  key2  key3  key5  key6
# 0     1   4.0   8.0  43.0   8.0
# 1     2   5.0   3.0   NaN   NaN
# 2     4   6.0   5.0   6.0   5.0
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   8.0  36.0
# 5    23   NaN   NaN  53.0  34.0
# 6    55   NaN   NaN   7.0   7.0

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     3
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key5  key6
# 0     1    43     8
# 1    23    53    34
# 2     4     6     5
# 3    55     7     7
# 4     6     8    36

# %%
pd.merge(data1,data2,how="cross")
# Out:
#     key1_x  key2  key3  key1_y  key5  key6
# 0        1     4     8       1    43     8
# 1        1     4     8      23    53    34
# 2        1     4     8       4     6     5
# 3        1     4     8      55     7     7
# 4        1     4     8       6     8    36
# 5        2     5     3       1    43     8
# 6        2     5     3      23    53    34
# 7        2     5     3       4     6     5
# 8        2     5     3      55     7     7
# 9        2     5     3       6     8    36
# 10       4     6     5       1    43     8
# 11       4     6     5      23    53    34
# 12       4     6     5       4     6     5
# 13       4     6     5      55     7     7
# 14       4     6     5       6     8    36
# 15       5     7     6       1    43     8
# 16       5     7     6      23    53    34
# 17       5     7     6       4     6     5
# 18       5     7     6      55     7     7
# 19       5     7     6       6     8    36
# 20       6     8     6       1    43     8
# ...

# %%
pd.merge(data1,data2,how="outer",on = "key1")
# Out:
#    key1  key2  key3  key5  key6
# 0     1   4.0   8.0  43.0   8.0
# 1     2   5.0   3.0   NaN   NaN
# 2     4   6.0   5.0   6.0   5.0
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   8.0  36.0
# 5    23   NaN   NaN  53.0  34.0
# 6    55   NaN   NaN   7.0   7.0

# %%
pd.merge(data1,data2,how="outer")
# Out:
#    key1  key2  key3  key5  key6
# 0     1   4.0   8.0  43.0   8.0
# 1     2   5.0   3.0   NaN   NaN
# 2     4   6.0   5.0   6.0   5.0
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   8.0  36.0
# 5    23   NaN   NaN  53.0  34.0
# 6    55   NaN   NaN   7.0   7.0

# %%
data3 = pd.DataFrame({'key1' : [1,2,4,5,6],
                      'key2' : [4,5,6,7,8],  ## giving row names
                      'key3' : [8,3,5,6,6]},
                       index = ['a','b','c','d','e']
                     )

# %%
data3
# Out:
#    key1  key2  key3
# a     1     4     8
# b     2     5     3
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data4 = pd.DataFrame({'key11' : [11,2,4,5,6],
                      'key22' : [4,52,36,7,8],
                      'key33' : [8,3,5,36,46]},
                      index = ['a','b','h','i','j']

                    )

# %%
data4
# Out:
#    key11  key22  key33
# a     11      4      8
# b      2     52      3
# h      4     36      5
# i      5      7     36
# j      6      8     46

# %%
 ## merge  works on columns
 ## join works on indexes if indexes are same then it will match it will take left full data
data3.join(data4)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     8   11.0    4.0    8.0
# b     2     5     3    2.0   52.0    3.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data3.join(data4,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   8.0     11      4      8
# b   2.0   5.0   3.0      2     52      3
# h   NaN   NaN   NaN      4     36      5
# i   NaN   NaN   NaN      5      7     36
# j   NaN   NaN   NaN      6      8     46

# %%
data3.join(data4,how = 'inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     8     11      4      8
# b     2     5     3      2     52      3

# %%
data3.join(data4,how = 'outer') ## all functions will  be work same as merge . only difference is column and index
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   8.0   11.0    4.0    8.0
# b   2.0   5.0   3.0    2.0   52.0    3.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0   36.0    5.0
# i   NaN   NaN   NaN    5.0    7.0   36.0
# j   NaN   NaN   NaN    6.0    8.0   46.0

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['FARE_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    FARE_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
def euro(x):
    return x*80
df['FARE_INR'] = df['Fare'].apply(euro)

# %%
df["FARE_INR"]
# Out:
# 0       580.000
# 1      5702.664
# 2       634.000
# 3       644.000
# 4       676.664
#          ...
# 885    1040.000
# 886    2400.000
# 887    1876.000
# 888    2400.000
# 889     620.000
# Name: FARE_INR, Length: 890, dtype: float64

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    FARE_INR  Fare_INR
# 0   580.000   580.000
# 1  5702.664  5702.664
# 2   634.000   634.000
# ...

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    FARE_INR  Fare_INR  name_len
# 0   580.000   580.000        23
# 1  5702.664  5702.664        51
# ...

# %%
df['name_len']
# Out:
# 0      23
# 1      51
# 2      22
# 3      24
# 4      16
#        ..
# 885    21
# 886    28
# 887    40
# 888    21
# 889    19
# Name: name_len, Length: 890, dtype: int64

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid"
    else:
        return "high"

# %%
df["cat_fare"] = df['Fare'].apply(cat_fare)

# %%
df["cat_fare"]
# Out:
# 0      cheap
# 1       high
# 2      cheap
# 3      cheap
# 4      cheap
#        ...
# 885      mid
# 886     high
# 887     high
# 888     high
# 889    cheap
# Name: cat_fare, Length: 890, dtype: object

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...
